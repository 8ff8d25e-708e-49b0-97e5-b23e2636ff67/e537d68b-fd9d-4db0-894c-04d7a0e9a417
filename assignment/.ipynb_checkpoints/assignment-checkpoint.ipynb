# %%
@bind("receptor","csv useHeaders=true","./disk/assignment/data/csvs","receptors.csv").
% @bind("isParentOf", "csv useHeaders=true", "./disk/kgs", "parents.csv").

% neo4j.url	bolt://localhost:7687	URL for connecting to the Neo4j instance using Bolt protocol.
% neo4j.username	neo4j	Username for authenticating to the Neo4j database.
% neo4j.password	neo4j	Password for authenticating to the Neo4j database.
% neo4j.authentication.type	basic	Type of authentication to use with Neo4j (options: none, basic, kerberos, custom, bearer).
% neo4j.relationshipNodesMap	false	Flag to determine if relationship nodes should be mapped.
% neo4j.chase.url	bolt://localhost:7687	URL for storing chase data in Neo4j.
% neo4j.chase.username	neo4j	Username for authenticating to Neo4j for chase storage.
% neo4j.chase.password	neo4j	Password for authenticating to Neo4j for chase storage.
% neo4j.chase.authenticationType	basic	Authentication type for chase storage in Neo4j (same options as general Neo4j config).

% receptor(Type,FamilyId,FamilyName,TargetId,TargetName,SubunitId,SubunitName,TargetName,TargetAbbrev,Synonyms,HGNCId,HGNCSymbol,HGNCName,HumanGeneticLocalisation,HumanNucleotideRefSeq,HumanProteinRefSeq,HumanSwissProt,HumanEntrezGene,HumanEnsemblGene).
% receptor(Type,FamilyId,FamilyName,TargetId,TargetName,_,_,_,_,_,_,_,_,_,_,_,_,_,_).

hormoneReceptorType(Id) :- receptor(Id,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_).
hormoneReceptorFamily(Id,Name) :- receptor(_,Id,Name,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_).
hormoneReceptorTarget(Id,Name,Synonym,Symbol,FullName) :- receptor(_,_,_,Id,Name,_,_,_,_,Synonym,_,Symbol,FullName,_,_,_,_,_,_).

partOfT(FamilyId,TypeId) :- receptor(TypeId,FamilyId,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_).
partOfF(TargetId,FamilyId) :- receptor(_,FamilyId,_,TargetId,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_).
partOfName(TargetName,FamilyName) :- 
    hormoneReceptorFamily(FamilyId,FamilyName),
    hormoneReceptorTarget(TargetId,TargetName,_,_,_),
    partOfF(TargetId,FamilyId),
    FamilyName = "Class A Orphans with no pharmacology".

partOfTransitive(A,B) :- partOf(A,B).
partOfTransitive(A,B) :- partOfTransitive(A,Via), partOf(Via,B).
    

% partOfT(FamilyId,TypeId) :- receptor(_,_,_,Id,Name,_,_,_,_,Synonym,_,Symbol,FullName,_,_,_,_,_,_).
% partOfF(TargetId,FamilyId) :- hormoneReceptorTarget(TargetId,_,_,_,_),hormoneReceptorFamily(FamilyId,_).


% @output("hormoneReceptorType").
% @output("hormoneReceptorFamily").
% @chase("csv", "./disk/assignment/data", "chase.csv").
@output("hormoneReceptorFamily").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
# ...

# %%
@bind("receptor","csv useHeaders=true","./disk/assignment/data/csvs","receptors.csv").

receptorCsv(Type,FamilyId,FamilyName,TargetId,TargetName,SubunitId,SubunitName,TargetName,TargetAbbrev,Synonyms,HGNCId,HGNCSymbol,HGNCName,HumanGeneticLocalisation,HumanNucleotideRefSeq,HumanProteinRefSeq,HumanSwissProt,HumanEntrezGene,HumanEnsemblGene) :- receptor(Type,FamilyId,FamilyName,TargetId,TargetName,SubunitId,SubunitName,TargetName,TargetAbbrev,Synonyms,HGNCId,HGNCSymbol,HGNCName,HumanGeneticLocalisation,HumanNucleotideRefSeq,HumanProteinRefSeq,HumanSwissProt,HumanEntrezGene,HumanEnsemblGene).

@output("receptorCsv").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
# ...
