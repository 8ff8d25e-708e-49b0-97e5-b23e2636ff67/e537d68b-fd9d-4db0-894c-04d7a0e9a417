# %%
@bind("hormoneI","csv useHeaders=true","./disk/assignment/data/csvs","hormones-detailed.csv").
hormone(HormoneId,HormoneGroupId,Abbrev,Hormone,ReceptorSwissProt,Receptor,Modulator,Description) :-
    hormoneI(HormoneId,HormoneGroupId,Abbrev,Hormone,ReceptorSwissProt,Receptor,Modulator,Description).
@output("hormone").

# %%
% We need to add the missing hormones from the precursors imports
@bind("hormoneI","csv useHeaders=true","./disk/assignment/data/csvs","hormones-detailed.csv").
@bind("pivotTableI","csv useHeaders=true","./disk/assignment/data/csvs","pivot-table.csv").

pivotTable(Hormone,HormoneId,LipidMapsId,PrecursorId,ClassicId,GlucoId,MineraloId,ClassicXhref,ClassicId2) :-
    pivotTableI(Hormone,HormoneId,LipidMapsId,PrecursorId,ClassicId,GlucoId,MineraloId,ClassicXhref,ClassicId2).

hormone(HormoneId,HormoneGroupId,Abbrev,Hormone,ReceptorSwissProt,Receptor,Modulator,Description) :-
    hormoneI(HormoneId,HormoneGroupId,Abbrev,Hormone,ReceptorSwissProt,Receptor,Modulator,Description).

pivotHormones(Hormone,HormoneId) :-
    pivotTableI(Hormone,PHormoneId,LipidMapsId,PrecursorId,ClassicId,GlucoId,MineraloId,ClassicXhref,ClassicId2),
    PHormoneId=NULL,
    LipidMapsId!=NULL,
    HormoneId=LipidMapsId.
pivotHormones(Hormone,HormoneId) :-
    pivotTableI(Hormone,PHormoneId,LipidMapsId,PrecursorId,ClassicId,GlucoId,MineraloId,ClassicXhref,ClassicId2),
    PHormoneId=NULL,
    LipidMapsId=NULL,
    ClassicXhref!=NULL,
    HormoneId=ClassicXhref.

hormone(HormoneId,_,_,Hormone,_,_,_,_):- 
    pivotHormones(Hormone,HormoneId).


@output("hormone").

% @bind("hormone","csv useHeaders=true","./disk/assignment/data/csvs","hormones.csv").

% @output("hormone").
% @output("pivotTable").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === RUN MODULE === */
# .run-module-result-caption {
#     color: rgb(56, 61, 65);
#     background-color: rgb(226, 227, 229);
#     border: 1px solid rgb(214, 216, 219);
# }
#
# .module-run-result-success {
#     color: rgb(21, 87, 36);
# }
# .module-run-result-unsuccess {
#     color: rgb(114, 28, 36);
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"></div>

# %%
@bind("hormoneI","csv useHeaders=true","./disk/assignment/data/csvs","hormones.csv").
@bind("pivotTable","csv useHeaders=true","./disk/assignment/data/csvs","pivot-table-ids.csv").

@bind("classicEdges","csv useHeaders=true","./disk/assignment/data/csvs","classic-edges.csv").
@bind("precursorEdges","csv useHeaders=true","./disk/assignment/data/csvs","precursor-edges.csv").
@bind("mineraloCorticoidEdges","csv useHeaders=true","./disk/assignment/data/csvs","mineralocorticoid-edges.csv").
@bind("glucocorticoidEdges","csv useHeaders=true","./disk/assignment/data/csvs","glucocorticoid-edges.csv").

hormone(HormoneId,HormoneGroupId,Abbrev,Hormone,ReceptorSwissProt,Receptor,Modulator,Description) :-
    hormoneI(HormoneId,HormoneGroupId,Abbrev,Hormone,ReceptorSwissProt,Receptor,Modulator,Description).

% pivotTable(Hormone,HormoneId,LipidMapsId,PrecursorId,ClassicId,GlucoId,MineraloId,ClassicXhref,ClassicId2).

classicTranslations(HormoneId,EdgeId) :-
    pivotTable(Hormone,HormoneId,LipidMapsId,PrecursorId,EdgeId,GlucoId,MineraloId,ClassicXhref,ClassicId2),
    EdgeId!=NULL.
classicTranslations(HormoneId,EdgeId) :-
    pivotTable(Hormone,HormoneId,LipidMapsId,PrecursorId,ClassicId,GlucoId,MineraloId,ClassicXhref,EdgeId),
    EdgeId!=NULL.

isPrecursorTo(HormoneIdFrom,HormoneIdTo) :-
    classicEdges(FromClassicId,IsAttachedToClassicId),
    classicTranslations(HormoneIdFrom,FromClassicId),
    classicTranslations(HormoneIdTo,IsAttachedToClassicId).

isPrecursorTo(HormoneIdFrom,HormoneIdTo) :-
    precursorEdges(FromPrecursorId,IsAttachedToPrecursorId),
    pivotTable(Hormone,HormoneIdFrom,LipidMapsId,FromPrecursorId,ClassicId,GlucoId,MineraloId,ClassicXhref,ClassicId2),
    pivotTable(Hormone,HormoneIdTo,LipidMapsId,IsAttachedToPrecursorId,ClassicId,GlucoId,MineraloId,ClassicXhref,ClassicId2).

isPrecursorTo(HormoneIdFrom,HormoneIdTo) :-
    mineraloCorticoidEdges(FromId,IsAttachedToId),
    pivotTable(Hormone,HormoneId,LipidMapsId,PrecursorId,ClassicId,GlucoId,MineraloId,ClassicXhref,ClassicId2).

@output("isPrecursorTo").
# Out:
#     <style>
# /* === TABLE === */
#
# .vadalog-output {
#     margin-top: 8px;
#     width: 100%;
#     vertical-align: text-top;
# }
#
# .vadalog-output-block {
# 	display: block;
# }
#
# .vadalog-output-block-scroll {
#     .vadalog-output-block
# 	overflow-x: auto;
# }
#
# .vadalog-output-block-inline-scroll {
# 	display: inline-block;
# 	margin-right:8px;
# 	overflow-x: auto;
# 	vertical-align: text-top;
# }
#
# .vadalog-output-table-wrap {
# 	display: table;
# }
#
# .vadalog-output-no-data-wide {
#     text-align: left;
#     padding: 4px 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
#     margin-bottom: 8px;
#     margin-top: 8px;
#     width:auto;
#     overflow-x: auto;
# }
#
# .vadalog-wide-table {
# 	width:100%;
# }
#
# .vadalog-300px-min-wide-table {
# 	min-width: 300px;
# }
#
# .vadalog-output-table-wrap table {
#     border-collapse: collapse;
# }
# .vadalog-output-table-wrap table caption {
#     display: table-caption;
#     text-align: left;
#     padding: 0 8px 4px 8px;
#     font-weight: bold;
#     font-size: 12px;
# }
#
# .vadalog-output-table-wrap table td,
# .vadalog-output-table-wrap table th {
#     border: 1px solid rgb(221, 221, 221);
#     background-color: rgba(0,0,0,0) !important;
#     text-align: left;
#     color: rgb(51, 51, 51) !important;
# }
# .vadalog-output-table-wrap table td {
# 	padding-top: 1px;
#     padding-bottom: 1px;
# }
# .vadalog-output-table-wrap table th {
# 	padding-top: 2px;
#     padding-bottom: 2px;
#     background-color: white !important;
# }
#
# .vadalog-output-table-wrap table tr {
# 	background-color: rgba(0,0,0,0)!important;
# }
#
# .vadalog-output-table-wrap table tbody:nth-child(odd){background-color: rgb(245, 245, 245);}
# .vadalog-output-table-wrap table tbody:nth-child(even){background-color: white;}
# .vadalog-output-table-wrap table tbody:hover td[rowspan], tr:hover td {background-color: #ddd !important;}
#
# .vadalog-output-table-wrap table th {
#     text-align: left;
# }
#
# /* === RUN MODULE === */
# .run-module-result-caption {
#     color: rgb(56, 61, 65);
#     background-color: rgb(226, 227, 229);
#     border: 1px solid rgb(214, 216, 219);
# }
#
# .module-run-result-success {
#     color: rgb(21, 87, 36);
# }
# .module-run-result-unsuccess {
#     color: rgb(114, 28, 36);
# }
#
# /* === CODE ANALYSIS === */
# .vadalog-code-analysis-warning {
#     color: rgb(133, 100, 4);
# 	background-color: rgb(255, 243, 205);
# 	border: 1px solid rgb(255, 238, 186);
# }
# .vadalog-code-analysis-error {
#     color: rgb(114, 28, 36);
# 	background-color: rgb(248, 215, 218);
# 	border: 1px solid rgb(245, 198, 203);
# }
# .vadalog-code-analysis-note {
#     color: rgb(12, 84, 96);
#     background-color: rgb(209, 236, 241);
#     border: 1px solid rgb(190, 229, 235);
# }
# .vadalog-code-analysis-no-error {
#     color: rgb(21, 87, 36);
#     background-color: rgb(212, 237, 218);
#     border: 1px solid rgb(195, 230, 203);
# }
#
# .vadalog-table-caption {
#     color: rgb(0, 64, 133);
#     background-color: rgb(204, 229, 255);
#     border: 1px solid rgb(184, 218, 255);
# }
#
# /* === META PROGRAM === */
#
# .vadalog-output-block textarea.vadalog-meta-program-textarea {
#     width: 95%;
#     white-space: pre;
#     overflow: auto;
#     min-height: 80px;
# }
# </style>
# <div class="vadalog-output"><div class="vadalog-output-block-inline-scroll"><div class="vadalog-output-table-wrap"><table class="vadalog-300px-min-wide-table"><caption class="vadalog-table-caption">isPrecursorTo</caption><thead><tr><th>HormoneIdFrom</th><th>HormoneIdTo</th></tr></thead><tbody><tr><td>LMST02030089</td><td>d3d47191-a2c9-49da-b3f5-85909530b1c6</td></tr></tbody><tbody><tr><td>24779614</td><td>LMST02030264</td></tr></tbody><tbody><tr><td>LMST02030264</td><td>CHEBI:26763</td></tr></tbody><tbody><tr><td>f215e8fd-ceb8-4ba9-a570-0576757d3af8</td><td>CHEBI:16469</td></tr></tbody><tbody><tr><td>LMST02030088</td><td>5bb70a76-a68d-42f5-95e1-c0c3fe844963</td></tr></tbody><tbody><tr><td>LMST02030269</td><td>24779614</td></tr></tbody><tbody><tr><td>5754</td><td>516-42-7</td></tr></tbody><tbody><tr><td>5bb70a76-a68d-42f5-95e1-c0c3fe844963</td><td>LMST02030269</td></tr></tbody><tbody><tr><td>1482-50-4</td><td>7f966adf-7c0c-4ac5-ad21-5285f12613b1</td></tr></tbody><tbody><tr><td>7fa16bfd-eb60-4e59-884c-a8fb91a24e29</td><td>7fca6ef2-8836-409b-a958-5287134aee49</td></tr></tbody><tbody><tr><td>CHEBI:58349</td><td>CHEBI:57783</td></tr></tbody><tbody><tr><td>7f966adf-7c0c-4ac5-ad21-5285f12613b1</td><td>